# %% [markdown]
# <a href="https://colab.research.google.com/github/Clalloures/Machine-Learning/blob/master/visualizandoK_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A primeira parte do nosso código será importar as bibliotecas útesis

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import KMeans

# %% [markdown]
# Vamos gerar nossos próprios dados usando a função make_blobs do módulo sklearn.datasets. O parâmetro centers especifica o número de clusters.

# %%
X, y = make_blobs(n_samples=200, centers=3, cluster_std=0.5, random_state=0)
plt.scatter(X[:,0], X[:,1])

# %% [markdown]
# Vamos categorizar os dados usando o número ideal de clusters que determinamos na última etapa. k-means ++ garante que você não caia na armadilha de inicialização aleatória.

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=200, n_init=10, random_state=0)
pred_y = kmeans.fit_predict(X)
plt.scatter(X[:,0], X[:,1])
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='purple')
plt.show()
